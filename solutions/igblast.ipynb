# %% [markdown]
# # IgBLAST

# %% [markdown]
# Given the following FASTA file, use IgBLAST to assign germline V, D, and J segments, and post-process using Change-O.

# %% [markdown]
# ## Set up IgBLAST

# %%
# %%bash
# wget -r -nH --cut-dirs=4 --no-parent ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data
# wget -r -nH --cut-dirs=4 --no-parent ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/optional_file
# Out:
# --2016-10-22 06:58:05--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data
#            => ‘.listing’
# Resolving ftp.ncbi.nih.gov (ftp.ncbi.nih.gov)... 130.14.250.11, 2607:f220:41e:250::13
# Connecting to ftp.ncbi.nih.gov (ftp.ncbi.nih.gov)|130.14.250.11|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /blast/executables/igblast/release ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K                                                        15.6K=0.04s
#
# 2016-10-22 06:58:07 (15.6 KB/s) - ‘.listing’ saved [599]
#
# Removed ‘.listing’.
# --2016-10-22 06:58:07--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/internal_data
#            => ‘internal_data/.listing’
# ==> CWD (1) /blast/executables/igblast/release/internal_data ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K                                                         227K=0.001s
#
# 2016-10-22 06:58:07 (227 KB/s) - ‘internal_data/.listing’ saved [322]
#
# Removed ‘internal_data/.listing’.
# --2016-10-22 06:58:07--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/internal_data
#            => ‘internal_data/human/.listing’
# ==> CWD (1) /blast/executables/igblast/release/internal_data/human ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                       320M=0s
#
# 2016-10-22 06:58:08 (320 MB/s) - ‘internal_data/human/.listing’ saved [1982]
#
# Removed ‘internal_data/human/.listing’.
# --2016-10-22 06:58:08--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human.ndm.imgt
#            => ‘internal_data/human/human.ndm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human.ndm.imgt ... done.
# Length: 52055 (51K)
#
#      0K .......... .......... .......... .......... .......... 98% 97.0K 0s
#     50K                                                       100% 1593G=0.5s
#
# 2016-10-22 06:58:09 (98.6 KB/s) - ‘internal_data/human/human.ndm.imgt’ saved [52055]
#
# --2016-10-22 06:58:09--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human.ndm.kabat
#            => ‘internal_data/human/human.ndm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human.ndm.kabat ... done.
# Length: 30893 (30K)
#
#      0K .......... .......... ..........                      100%  124K=0.2s
#
# 2016-10-22 06:58:10 (124 KB/s) - ‘internal_data/human/human.ndm.kabat’ saved [30893]
#
# --2016-10-22 06:58:10--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human.pdm.imgt
#            => ‘internal_data/human/human.pdm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human.pdm.imgt ... done.
# Length: 34374 (34K)
#
#      0K .......... .......... .......... ...                  100%  151K=0.2s
#
# 2016-10-22 06:58:10 (151 KB/s) - ‘internal_data/human/human.pdm.imgt’ saved [34374]
#
# --2016-10-22 06:58:10--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human.pdm.kabat
#            => ‘internal_data/human/human.pdm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human.pdm.kabat ... done.
# Length: 26769 (26K)
#
#      0K .......... .......... ......                          100%  179K=0.1s
#
# 2016-10-22 06:58:11 (179 KB/s) - ‘internal_data/human/human.pdm.kabat’ saved [26769]
#
# --2016-10-22 06:58:11--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.nhr
#            => ‘internal_data/human/human_TR_V.nhr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.nhr ... done.
# Length: 7472 (7.3K)
#
#      0K .......                                               100% 95.3K=0.08s
#
# 2016-10-22 06:58:12 (95.3 KB/s) - ‘internal_data/human/human_TR_V.nhr’ saved [7472]
#
# --2016-10-22 06:58:12--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.nin
#            => ‘internal_data/human/human_TR_V.nin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.nin ... done.
# Length: 1528 (1.5K)
#
#      0K .                                                     100% 75.9K=0.02s
#
# 2016-10-22 06:58:12 (75.9 KB/s) - ‘internal_data/human/human_TR_V.nin’ saved [1528]
#
# --2016-10-22 06:58:12--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.nog
#            => ‘internal_data/human/human_TR_V.nog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.nog ... done.
# Length: 516
#
#      0K                                                       100% 22.1K=0.02s
#
# 2016-10-22 06:58:13 (22.1 KB/s) - ‘internal_data/human/human_TR_V.nog’ saved [516]
#
# --2016-10-22 06:58:13--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.nsd
#            => ‘internal_data/human/human_TR_V.nsd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.nsd ... done.
# Length: 3834 (3.7K)
#
#      0K ...                                                   100% 46.8K=0.08s
#
# 2016-10-22 06:58:13 (46.8 KB/s) - ‘internal_data/human/human_TR_V.nsd’ saved [3834]
#
# --2016-10-22 06:58:13--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.nsi
#            => ‘internal_data/human/human_TR_V.nsi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.nsi ... done.
# Length: 141
#
#      0K                                                       100% 10.3K=0.01s
#
# 2016-10-22 06:58:14 (10.3 KB/s) - ‘internal_data/human/human_TR_V.nsi’ saved [141]
#
# --2016-10-22 06:58:14--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.nsq
#            => ‘internal_data/human/human_TR_V.nsq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.nsq ... done.
# Length: 8705 (8.5K)
#
#      0K ........                                              100%  117K=0.07s
#
# 2016-10-22 06:58:14 (117 KB/s) - ‘internal_data/human/human_TR_V.nsq’ saved [8705]
#
# --2016-10-22 06:58:14--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.phr
#            => ‘internal_data/human/human_TR_V.phr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.phr ... done.
# Length: 7279 (7.1K)
#
#      0K .......                                               100%  102K=0.07s
#
# 2016-10-22 06:58:15 (102 KB/s) - ‘internal_data/human/human_TR_V.phr’ saved [7279]
#
# --2016-10-22 06:58:15--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.pin
#            => ‘internal_data/human/human_TR_V.pin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.pin ... done.
# Length: 1008
#
#      0K                                                       100% 47.9K=0.02s
#
# 2016-10-22 06:58:15 (47.9 KB/s) - ‘internal_data/human/human_TR_V.pin’ saved [1008]
#
# --2016-10-22 06:58:15--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.pog
#            => ‘internal_data/human/human_TR_V.pog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.pog ... done.
# Length: 496
#
#      0K                                                       100% 10.1K=0.05s
#
# 2016-10-22 06:58:16 (10.1 KB/s) - ‘internal_data/human/human_TR_V.pog’ saved [496]
#
# --2016-10-22 06:58:16--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.psd
#            => ‘internal_data/human/human_TR_V.psd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.psd ... done.
# Length: 3666 (3.6K)
#
#      0K ...                                                   100%  115K=0.03s
#
# 2016-10-22 06:58:16 (115 KB/s) - ‘internal_data/human/human_TR_V.psd’ saved [3666]
#
# --2016-10-22 06:58:16--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.psi
#            => ‘internal_data/human/human_TR_V.psi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.psi ... done.
# Length: 136
#
#      0K                                                       100% 1.67K=0.08s
#
# 2016-10-22 06:58:17 (1.67 KB/s) - ‘internal_data/human/human_TR_V.psi’ saved [136]
#
# --2016-10-22 06:58:17--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_TR_V.psq
#            => ‘internal_data/human/human_TR_V.psq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_TR_V.psq ... done.
# Length: 11193 (11K)
#
#      0K ..........                                            100%  483K=0.02s
#
# 2016-10-22 06:58:17 (483 KB/s) - ‘internal_data/human/human_TR_V.psq’ saved [11193]
#
# --2016-10-22 06:58:17--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.nhr
#            => ‘internal_data/human/human_V.nhr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.nhr ... done.
# Length: 14759 (14K)
#
#      0K .......... ....                                       100%  158K=0.09s
#
# 2016-10-22 06:58:18 (158 KB/s) - ‘internal_data/human/human_V.nhr’ saved [14759]
#
# --2016-10-22 06:58:18--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.nin
#            => ‘internal_data/human/human_V.nin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.nin ... done.
# Length: 3700 (3.6K)
#
#      0K ...                                                   100%  131K=0.03s
#
# 2016-10-22 06:58:18 (131 KB/s) - ‘internal_data/human/human_V.nin’ saved [3700]
#
# --2016-10-22 06:58:18--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.nog
#            => ‘internal_data/human/human_V.nog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.nog ... done.
# Length: 1240 (1.2K)
#
#      0K .                                                     100% 22.5K=0.05s
#
# 2016-10-22 06:58:19 (22.5 KB/s) - ‘internal_data/human/human_V.nog’ saved [1240]
#
# --2016-10-22 06:58:19--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.nsd
#            => ‘internal_data/human/human_V.nsd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.nsd ... done.
# Length: 9970 (9.7K)
#
#      0K .........                                             100%  391K=0.02s
#
# 2016-10-22 06:58:20 (391 KB/s) - ‘internal_data/human/human_V.nsd’ saved [9970]
#
# --2016-10-22 06:58:20--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.nsi
#            => ‘internal_data/human/human_V.nsi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.nsi ... done.
# Length: 279
#
#      0K                                                       100% 4.54K=0.06s
#
# 2016-10-22 06:58:20 (4.54 KB/s) - ‘internal_data/human/human_V.nsi’ saved [279]
#
# --2016-10-22 06:58:20--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.nsq
#            => ‘internal_data/human/human_V.nsq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.nsq ... done.
# Length: 22083 (22K)
#
#      0K .......... .......... .                               100%  150K=0.1s
#
# 2016-10-22 06:58:21 (150 KB/s) - ‘internal_data/human/human_V.nsq’ saved [22083]
#
# --2016-10-22 06:58:21--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.phr
#            => ‘internal_data/human/human_V.phr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.phr ... done.
# Length: 10349 (10K)
#
#      0K ..........                                            100% 73.4K=0.1s
#
# 2016-10-22 06:58:21 (73.4 KB/s) - ‘internal_data/human/human_V.phr’ saved [10349]
#
# --2016-10-22 06:58:21--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.pin
#            => ‘internal_data/human/human_V.pin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.pin ... done.
# Length: 1712 (1.7K)
#
#      0K .                                                     100% 10.9K=0.2s
#
# 2016-10-22 06:58:22 (10.9 KB/s) - ‘internal_data/human/human_V.pin’ saved [1712]
#
# --2016-10-22 06:58:22--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.pog
#            => ‘internal_data/human/human_V.pog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.pog ... done.
# Length: 848
#
#      0K                                                       100% 58.0K=0.01s
#
# 2016-10-22 06:58:22 (58.0 KB/s) - ‘internal_data/human/human_V.pog’ saved [848]
#
# --2016-10-22 06:58:22--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.psd
#            => ‘internal_data/human/human_V.psd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.psd ... done.
# Length: 7422 (7.2K)
#
#      0K .......                                               100%  588K=0.01s
#
# 2016-10-22 06:58:23 (588 KB/s) - ‘internal_data/human/human_V.psd’ saved [7422]
#
# --2016-10-22 06:58:23--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.psi
#            => ‘internal_data/human/human_V.psi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.psi ... done.
# Length: 225
#
#      0K                                                       100% 6.34K=0.03s
#
# 2016-10-22 06:58:23 (6.34 KB/s) - ‘internal_data/human/human_V.psi’ saved [225]
#
# --2016-10-22 06:58:23--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/human/human_V.psq
#            => ‘internal_data/human/human_V.psq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_V.psq ... done.
# Length: 20258 (20K)
#
#      0K .......... .........                                  100%  142K=0.1s
#
# 2016-10-22 06:58:24 (142 KB/s) - ‘internal_data/human/human_V.psq’ saved [20258]
#
# --2016-10-22 06:58:24--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/internal_data
#            => ‘internal_data/mouse/.listing’
# ==> CWD (1) /blast/executables/igblast/release/internal_data/mouse ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                       404M=0s
#
# 2016-10-22 06:58:25 (404 MB/s) - ‘internal_data/mouse/.listing’ saved [1982]
#
# Removed ‘internal_data/mouse/.listing’.
# --2016-10-22 06:58:25--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse.ndm.imgt
#            => ‘internal_data/mouse/mouse.ndm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse.ndm.imgt ... done.
# Length: 36352 (36K)
#
#      0K .......... .......... .......... .....                100%  122K=0.3s
#
# 2016-10-22 06:58:26 (122 KB/s) - ‘internal_data/mouse/mouse.ndm.imgt’ saved [36352]
#
# --2016-10-22 06:58:26--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse.ndm.kabat
#            => ‘internal_data/mouse/mouse.ndm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse.ndm.kabat ... done.
# Length: 22852 (22K)
#
#      0K .......... .......... ..                              100%  106K=0.2s
#
# 2016-10-22 06:58:26 (106 KB/s) - ‘internal_data/mouse/mouse.ndm.kabat’ saved [22852]
#
# --2016-10-22 06:58:26--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse.pdm.imgt
#            => ‘internal_data/mouse/mouse.pdm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse.pdm.imgt ... done.
# Length: 32106 (31K)
#
#      0K .......... .......... .......... .                    100%  135K=0.2s
#
# 2016-10-22 06:58:27 (135 KB/s) - ‘internal_data/mouse/mouse.pdm.imgt’ saved [32106]
#
# --2016-10-22 06:58:27--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse.pdm.kabat
#            => ‘internal_data/mouse/mouse.pdm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse.pdm.kabat ... done.
# Length: 19641 (19K)
#
#      0K .......... .........                                  100%  140K=0.1s
#
# 2016-10-22 06:58:28 (140 KB/s) - ‘internal_data/mouse/mouse.pdm.kabat’ saved [19641]
#
# --2016-10-22 06:58:28--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.nhr
#            => ‘internal_data/mouse/mouse_TR_V.nhr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.nhr ... done.
# Length: 9768 (9.5K)
#
#      0K .........                                             100% 90.4K=0.1s
#
# 2016-10-22 06:58:28 (90.4 KB/s) - ‘internal_data/mouse/mouse_TR_V.nhr’ saved [9768]
#
# --2016-10-22 06:58:28--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.nin
#            => ‘internal_data/mouse/mouse_TR_V.nin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.nin ... done.
# Length: 1948 (1.9K)
#
#      0K .                                                     100% 19.7K=0.1s
#
# 2016-10-22 06:58:29 (19.7 KB/s) - ‘internal_data/mouse/mouse_TR_V.nin’ saved [1948]
#
# --2016-10-22 06:58:29--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.nog
#            => ‘internal_data/mouse/mouse_TR_V.nog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.nog ... done.
# Length: 656
#
#      0K                                                       100% 28.5K=0.02s
#
# 2016-10-22 06:58:29 (28.5 KB/s) - ‘internal_data/mouse/mouse_TR_V.nog’ saved [656]
#
# --2016-10-22 06:58:29--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.nsd
#            => ‘internal_data/mouse/mouse_TR_V.nsd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.nsd ... done.
# Length: 5276 (5.2K)
#
#      0K .....                                                 100%  641K=0.008s
#
# 2016-10-22 06:58:30 (641 KB/s) - ‘internal_data/mouse/mouse_TR_V.nsd’ saved [5276]
#
# --2016-10-22 06:58:30--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.nsi
#            => ‘internal_data/mouse/mouse_TR_V.nsi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.nsi ... done.
# Length: 169
#
#      0K                                                       100% 4.09K=0.04s
#
# 2016-10-22 06:58:30 (4.09 KB/s) - ‘internal_data/mouse/mouse_TR_V.nsi’ saved [169]
#
# --2016-10-22 06:58:30--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.nsq
#            => ‘internal_data/mouse/mouse_TR_V.nsq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.nsq ... done.
# Length: 11102 (11K)
#
#      0K ..........                                            100% 74.9K=0.1s
#
# 2016-10-22 06:58:31 (74.9 KB/s) - ‘internal_data/mouse/mouse_TR_V.nsq’ saved [11102]
#
# --2016-10-22 06:58:31--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.phr
#            => ‘internal_data/mouse/mouse_TR_V.phr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.phr ... done.
# Length: 9422 (9.2K)
#
#      0K .........                                             100%  979K=0.009s
#
# 2016-10-22 06:58:31 (979 KB/s) - ‘internal_data/mouse/mouse_TR_V.phr’ saved [9422]
#
# --2016-10-22 06:58:31--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.pin
#            => ‘internal_data/mouse/mouse_TR_V.pin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.pin ... done.
# Length: 1264 (1.2K)
#
#      0K .                                                     100% 65.1K=0.02s
#
# 2016-10-22 06:58:32 (65.1 KB/s) - ‘internal_data/mouse/mouse_TR_V.pin’ saved [1264]
#
# --2016-10-22 06:58:32--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.pog
#            => ‘internal_data/mouse/mouse_TR_V.pog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.pog ... done.
# Length: 624
#
#      0K                                                       100% 10.7K=0.06s
#
# 2016-10-22 06:58:32 (10.7 KB/s) - ‘internal_data/mouse/mouse_TR_V.pog’ saved [624]
#
# --2016-10-22 06:58:32--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.psd
#            => ‘internal_data/mouse/mouse_TR_V.psd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.psd ... done.
# Length: 5008 (4.9K)
#
#      0K ....                                                  100%  114K=0.04s
#
# 2016-10-22 06:58:33 (114 KB/s) - ‘internal_data/mouse/mouse_TR_V.psd’ saved [5008]
#
# --2016-10-22 06:58:33--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.psi
#            => ‘internal_data/mouse/mouse_TR_V.psi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.psi ... done.
# Length: 170
#
#      0K                                                       100% 3.01K=0.06s
#
# 2016-10-22 06:58:33 (3.01 KB/s) - ‘internal_data/mouse/mouse_TR_V.psi’ saved [170]
#
# --2016-10-22 06:58:33--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_TR_V.psq
#            => ‘internal_data/mouse/mouse_TR_V.psq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_TR_V.psq ... done.
# Length: 14144 (14K)
#
#      0K .......... ...                                        100% 34.6K=0.4s
#
# 2016-10-22 06:58:35 (34.6 KB/s) - ‘internal_data/mouse/mouse_TR_V.psq’ saved [14144]
#
# --2016-10-22 06:58:35--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.nhr
#            => ‘internal_data/mouse/mouse_V.nhr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.nhr ... done.
# Length: 30218 (30K)
#
#      0K .......... .......... .........                       100%  123K=0.2s
#
# 2016-10-22 06:58:36 (123 KB/s) - ‘internal_data/mouse/mouse_V.nhr’ saved [30218]
#
# --2016-10-22 06:58:36--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.nin
#            => ‘internal_data/mouse/mouse_V.nin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.nin ... done.
# Length: 7708 (7.5K)
#
#      0K .......                                               100%  106K=0.07s
#
# 2016-10-22 06:58:36 (106 KB/s) - ‘internal_data/mouse/mouse_V.nin’ saved [7708]
#
# --2016-10-22 06:58:36--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.nog
#            => ‘internal_data/mouse/mouse_V.nog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.nog ... done.
# Length: 2576 (2.5K)
#
#      0K ..                                                    100% 61.2K=0.04s
#
# 2016-10-22 06:58:37 (61.2 KB/s) - ‘internal_data/mouse/mouse_V.nog’ saved [2576]
#
# --2016-10-22 06:58:37--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.nsd
#            => ‘internal_data/mouse/mouse_V.nsd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.nsd ... done.
# Length: 19512 (19K)
#
#      0K .......... .........                                  100%  124K=0.2s
#
# 2016-10-22 06:58:37 (124 KB/s) - ‘internal_data/mouse/mouse_V.nsd’ saved [19512]
#
# --2016-10-22 06:58:37--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.nsi
#            => ‘internal_data/mouse/mouse_V.nsi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.nsi ... done.
# Length: 518
#
#      0K                                                       100% 9.29K=0.05s
#
# 2016-10-22 06:58:38 (9.29 KB/s) - ‘internal_data/mouse/mouse_V.nsi’ saved [518]
#
# --2016-10-22 06:58:38--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.nsq
#            => ‘internal_data/mouse/mouse_V.nsq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.nsq ... done.
# Length: 47719 (47K)
#
#      0K .......... .......... .......... .......... ......    100%  131K=0.4s
#
# 2016-10-22 06:58:39 (131 KB/s) - ‘internal_data/mouse/mouse_V.nsq’ saved [47719]
#
# --2016-10-22 06:58:39--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.phr
#            => ‘internal_data/mouse/mouse_V.phr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.phr ... done.
# Length: 24302 (24K)
#
#      0K .......... .......... ...                             100% 92.2K=0.3s
#
# 2016-10-22 06:58:39 (92.2 KB/s) - ‘internal_data/mouse/mouse_V.phr’ saved [24302]
#
# --2016-10-22 06:58:39--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.pin
#            => ‘internal_data/mouse/mouse_V.pin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.pin ... done.
# Length: 4176 (4.1K)
#
#      0K ....                                                  100% 22.0K=0.2s
#
# 2016-10-22 06:58:40 (22.0 KB/s) - ‘internal_data/mouse/mouse_V.pin’ saved [4176]
#
# --2016-10-22 06:58:40--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.pog
#            => ‘internal_data/mouse/mouse_V.pog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.pog ... done.
# Length: 2080 (2.0K)
#
#      0K ..                                                    100% 33.2K=0.06s
#
# 2016-10-22 06:58:41 (33.2 KB/s) - ‘internal_data/mouse/mouse_V.pog’ saved [2080]
#
# --2016-10-22 06:58:41--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.psd
#            => ‘internal_data/mouse/mouse_V.psd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.psd ... done.
# Length: 15616 (15K)
#
#      0K .......... .....                                      100%  157K=0.1s
#
# 2016-10-22 06:58:41 (157 KB/s) - ‘internal_data/mouse/mouse_V.psd’ saved [15616]
#
# --2016-10-22 06:58:41--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.psi
#            => ‘internal_data/mouse/mouse_V.psi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.psi ... done.
# Length: 414
#
#      0K                                                       100% 1.52K=0.3s
#
# 2016-10-22 06:58:42 (1.52 KB/s) - ‘internal_data/mouse/mouse_V.psi’ saved [414]
#
# --2016-10-22 06:58:42--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/mouse/mouse_V.psq
#            => ‘internal_data/mouse/mouse_V.psq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_V.psq ... done.
# Length: 50692 (50K)
#
#      0K .......... .......... .......... .......... ......... 100%  141K=0.4s
#
# 2016-10-22 06:58:43 (141 KB/s) - ‘internal_data/mouse/mouse_V.psq’ saved [50692]
#
# --2016-10-22 06:58:43--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/internal_data
#            => ‘internal_data/rabbit/.listing’
# ==> CWD (1) /blast/executables/igblast/release/internal_data/rabbit ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                       259M=0s
#
# 2016-10-22 06:58:43 (259 MB/s) - ‘internal_data/rabbit/.listing’ saved [1134]
#
# Removed ‘internal_data/rabbit/.listing’.
# --2016-10-22 06:58:43--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit.ndm.imgt
#            => ‘internal_data/rabbit/rabbit.ndm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit.ndm.imgt ... done.
# Length: 6565 (6.4K)
#
#      0K ......                                                100% 77.6K=0.08s
#
# 2016-10-22 06:58:44 (77.6 KB/s) - ‘internal_data/rabbit/rabbit.ndm.imgt’ saved [6565]
#
# --2016-10-22 06:58:44--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit.ndm.kabat
#            => ‘internal_data/rabbit/rabbit.ndm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit.ndm.kabat ... done.
# Length: 6694 (6.5K)
#
#      0K ......                                                100%  127K=0.05s
#
# 2016-10-22 06:58:44 (127 KB/s) - ‘internal_data/rabbit/rabbit.ndm.kabat’ saved [6694]
#
# --2016-10-22 06:58:44--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit.pdm.imgt
#            => ‘internal_data/rabbit/rabbit.pdm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit.pdm.imgt ... done.
# Length: 5808 (5.7K)
#
#      0K .....                                                 100% 32.5K=0.2s
#
# 2016-10-22 06:58:45 (32.5 KB/s) - ‘internal_data/rabbit/rabbit.pdm.imgt’ saved [5808]
#
# --2016-10-22 06:58:45--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit.pdm.kabat
#            => ‘internal_data/rabbit/rabbit.pdm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit.pdm.kabat ... done.
# Length: 5808 (5.7K)
#
#      0K .....                                                 100% 69.2K=0.08s
#
# 2016-10-22 06:58:46 (69.2 KB/s) - ‘internal_data/rabbit/rabbit.pdm.kabat’ saved [5808]
#
# --2016-10-22 06:58:46--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.nhr
#            => ‘internal_data/rabbit/rabbit_V.nhr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.nhr ... done.
# Length: 9156 (8.9K)
#
#      0K ........                                              100%  142K=0.06s
#
# 2016-10-22 06:58:46 (142 KB/s) - ‘internal_data/rabbit/rabbit_V.nhr’ saved [9156]
#
# --2016-10-22 06:58:46--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.nin
#            => ‘internal_data/rabbit/rabbit_V.nin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.nin ... done.
# Length: 1828 (1.8K)
#
#      0K .                                                     100%  212K=0.008s
#
# 2016-10-22 06:58:47 (212 KB/s) - ‘internal_data/rabbit/rabbit_V.nin’ saved [1828]
#
# --2016-10-22 06:58:47--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.nog
#            => ‘internal_data/rabbit/rabbit_V.nog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.nog ... done.
# Length: 616
#
#      0K                                                       100% 7.89K=0.08s
#
# 2016-10-22 06:58:47 (7.89 KB/s) - ‘internal_data/rabbit/rabbit_V.nog’ saved [616]
#
# --2016-10-22 06:58:47--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.nsd
#            => ‘internal_data/rabbit/rabbit_V.nsd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.nsd ... done.
# Length: 4952 (4.8K)
#
#      0K ....                                                  100%  144K=0.03s
#
# 2016-10-22 06:58:48 (144 KB/s) - ‘internal_data/rabbit/rabbit_V.nsd’ saved [4952]
#
# --2016-10-22 06:58:48--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.nsi
#            => ‘internal_data/rabbit/rabbit_V.nsi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.nsi ... done.
# Length: 166
#
#      0K                                                       100% 4.91K=0.03s
#
# 2016-10-22 06:58:48 (4.91 KB/s) - ‘internal_data/rabbit/rabbit_V.nsi’ saved [166]
#
# --2016-10-22 06:58:48--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.nsq
#            => ‘internal_data/rabbit/rabbit_V.nsq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.nsq ... done.
# Length: 10878 (11K)
#
#      0K ..........                                            100%  275K=0.04s
#
# 2016-10-22 06:58:49 (275 KB/s) - ‘internal_data/rabbit/rabbit_V.nsq’ saved [10878]
#
# --2016-10-22 06:58:49--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.phr
#            => ‘internal_data/rabbit/rabbit_V.phr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.phr ... done.
# Length: 9302 (9.1K)
#
#      0K .........                                             100% 53.4K=0.2s
#
# 2016-10-22 06:58:49 (53.4 KB/s) - ‘internal_data/rabbit/rabbit_V.phr’ saved [9302]
#
# --2016-10-22 06:58:49--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.pin
#            => ‘internal_data/rabbit/rabbit_V.pin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.pin ... done.
# Length: 1248 (1.2K)
#
#      0K .                                                     100% 13.3K=0.09s
#
# 2016-10-22 06:58:50 (13.3 KB/s) - ‘internal_data/rabbit/rabbit_V.pin’ saved [1248]
#
# --2016-10-22 06:58:50--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.pog
#            => ‘internal_data/rabbit/rabbit_V.pog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.pog ... done.
# Length: 616
#
#      0K                                                       100% 27.4K=0.02s
#
# 2016-10-22 06:58:50 (27.4 KB/s) - ‘internal_data/rabbit/rabbit_V.pog’ saved [616]
#
# --2016-10-22 06:58:50--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.psd
#            => ‘internal_data/rabbit/rabbit_V.psd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.psd ... done.
# Length: 4952 (4.8K)
#
#      0K ....                                                  100%  218K=0.02s
#
# 2016-10-22 06:58:51 (218 KB/s) - ‘internal_data/rabbit/rabbit_V.psd’ saved [4952]
#
# --2016-10-22 06:58:51--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.psi
#            => ‘internal_data/rabbit/rabbit_V.psi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.psi ... done.
# Length: 166
#
#      0K                                                       100% 8.90K=0.02s
#
# 2016-10-22 06:58:51 (8.90 KB/s) - ‘internal_data/rabbit/rabbit_V.psi’ saved [166]
#
# --2016-10-22 06:58:51--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rabbit/rabbit_V.psq
#            => ‘internal_data/rabbit/rabbit_V.psq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_V.psq ... done.
# Length: 14556 (14K)
#
#      0K .......... ....                                       100%  177K=0.08s
#
# 2016-10-22 06:58:52 (177 KB/s) - ‘internal_data/rabbit/rabbit_V.psq’ saved [14556]
#
# --2016-10-22 06:58:52--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/internal_data
#            => ‘internal_data/rat/.listing’
# ==> CWD (1) /blast/executables/igblast/release/internal_data/rat ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K .                                                      44.1K=0.02s
#
# 2016-10-22 06:58:53 (44.1 KB/s) - ‘internal_data/rat/.listing’ saved [1086]
#
# Removed ‘internal_data/rat/.listing’.
# --2016-10-22 06:58:53--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat.ndm.imgt
#            => ‘internal_data/rat/rat.ndm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat.ndm.imgt ... done.
# Length: 14592 (14K)
#
#      0K .......... ....                                       100%  630K=0.02s
#
# 2016-10-22 06:58:53 (630 KB/s) - ‘internal_data/rat/rat.ndm.imgt’ saved [14592]
#
# --2016-10-22 06:58:53--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat.ndm.kabat
#            => ‘internal_data/rat/rat.ndm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat.ndm.kabat ... done.
# Length: 14936 (15K)
#
#      0K .......... ....                                       100%  236K=0.06s
#
# 2016-10-22 06:58:54 (236 KB/s) - ‘internal_data/rat/rat.ndm.kabat’ saved [14936]
#
# --2016-10-22 06:58:54--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat.pdm.imgt
#            => ‘internal_data/rat/rat.pdm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat.pdm.imgt ... done.
# Length: 12931 (13K)
#
#      0K .......... ..                                         100%  614K=0.02s
#
# 2016-10-22 06:58:54 (614 KB/s) - ‘internal_data/rat/rat.pdm.imgt’ saved [12931]
#
# --2016-10-22 06:58:54--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat.pdm.kabat
#            => ‘internal_data/rat/rat.pdm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat.pdm.kabat ... done.
# Length: 12997 (13K)
#
#      0K .......... ..                                         100%  255K=0.05s
#
# 2016-10-22 06:58:55 (255 KB/s) - ‘internal_data/rat/rat.pdm.kabat’ saved [12997]
#
# --2016-10-22 06:58:55--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.nhr
#            => ‘internal_data/rat/rat_V.nhr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.nhr ... done.
# Length: 23763 (23K)
#
#      0K .......... .......... ...                             100% 87.4K=0.3s
#
# 2016-10-22 06:58:55 (87.4 KB/s) - ‘internal_data/rat/rat_V.nhr’ saved [23763]
#
# --2016-10-22 06:58:55--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.nin
#            => ‘internal_data/rat/rat_V.nin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.nin ... done.
# Length: 4612 (4.5K)
#
#      0K ....                                                  100%  141K=0.03s
#
# 2016-10-22 06:58:56 (141 KB/s) - ‘internal_data/rat/rat_V.nin’ saved [4612]
#
# --2016-10-22 06:58:56--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.nog
#            => ‘internal_data/rat/rat_V.nog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.nog ... done.
# Length: 1544 (1.5K)
#
#      0K .                                                     100% 22.9K=0.07s
#
# 2016-10-22 06:58:57 (22.9 KB/s) - ‘internal_data/rat/rat_V.nog’ saved [1544]
#
# --2016-10-22 06:58:57--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.nsd
#            => ‘internal_data/rat/rat_V.nsd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.nsd ... done.
# Length: 13286 (13K)
#
#      0K .......... ..                                         100%  509K=0.03s
#
# 2016-10-22 06:58:57 (509 KB/s) - ‘internal_data/rat/rat_V.nsd’ saved [13286]
#
# --2016-10-22 06:58:57--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.nsi
#            => ‘internal_data/rat/rat_V.nsi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.nsi ... done.
# Length: 355
#
#      0K                                                       100% 13.5K=0.03s
#
# 2016-10-22 06:58:58 (13.5 KB/s) - ‘internal_data/rat/rat_V.nsi’ saved [355]
#
# --2016-10-22 06:58:58--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.nsq
#            => ‘internal_data/rat/rat_V.nsq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.nsq ... done.
# Length: 27869 (27K)
#
#      0K .......... .......... .......                         100%  149K=0.2s
#
# 2016-10-22 06:58:58 (149 KB/s) - ‘internal_data/rat/rat_V.nsq’ saved [27869]
#
# --2016-10-22 06:58:58--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.phr
#            => ‘internal_data/rat/rat_V.phr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.phr ... done.
# Length: 24141 (24K)
#
#      0K .......... .......... ...                             100%  155K=0.2s
#
# 2016-10-22 06:58:59 (155 KB/s) - ‘internal_data/rat/rat_V.phr’ saved [24141]
#
# --2016-10-22 06:58:59--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.pin
#            => ‘internal_data/rat/rat_V.pin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.pin ... done.
# Length: 3096 (3.0K)
#
#      0K ...                                                   100% 27.9K=0.1s
#
# 2016-10-22 06:58:59 (27.9 KB/s) - ‘internal_data/rat/rat_V.pin’ saved [3096]
#
# --2016-10-22 06:58:59--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.pog
#            => ‘internal_data/rat/rat_V.pog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.pog ... done.
# Length: 1544 (1.5K)
#
#      0K .                                                     100% 17.4K=0.09s
#
# 2016-10-22 06:59:00 (17.4 KB/s) - ‘internal_data/rat/rat_V.pog’ saved [1544]
#
# --2016-10-22 06:59:00--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.psd
#            => ‘internal_data/rat/rat_V.psd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.psd ... done.
# Length: 13286 (13K)
#
#      0K .......... ..                                         100% 80.8K=0.2s
#
# 2016-10-22 06:59:01 (80.8 KB/s) - ‘internal_data/rat/rat_V.psd’ saved [13286]
#
# --2016-10-22 06:59:01--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.psi
#            => ‘internal_data/rat/rat_V.psi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.psi ... done.
# Length: 355
#
#      0K                                                       100% 8.62K=0.04s
#
# 2016-10-22 06:59:01 (8.62 KB/s) - ‘internal_data/rat/rat_V.psi’ saved [355]
#
# --2016-10-22 06:59:01--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rat/rat_V.psq
#            => ‘internal_data/rat/rat_V.psq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_V.psq ... done.
# Length: 37301 (36K)
#
#      0K .......... .......... .......... ......               100% 74.0K=0.5s
#
# 2016-10-22 06:59:02 (74.0 KB/s) - ‘internal_data/rat/rat_V.psq’ saved [37301]
#
# --2016-10-22 06:59:02--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/internal_data
#            => ‘internal_data/rhesus_monkey/.listing’
# ==> CWD (1) /blast/executables/igblast/release/internal_data/rhesus_monkey ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K ..                                                      256M=0s
#
# 2016-10-22 06:59:03 (256 MB/s) - ‘internal_data/rhesus_monkey/.listing’ saved [2231]
#
# Removed ‘internal_data/rhesus_monkey/.listing’.
# --2016-10-22 06:59:03--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey.ndm.imgt
#            => ‘internal_data/rhesus_monkey/rhesus_monkey.ndm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey.ndm.imgt ... done.
# Length: 8158 (8.0K)
#
#      0K .......                                               100% 43.5K=0.2s
#
# 2016-10-22 06:59:03 (43.5 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey.ndm.imgt’ saved [8158]
#
# --2016-10-22 06:59:03--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey.ndm.kabat
#            => ‘internal_data/rhesus_monkey/rhesus_monkey.ndm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey.ndm.kabat ... done.
# Length: 8216 (8.0K)
#
#      0K ........                                              100%  112K=0.07s
#
# 2016-10-22 06:59:04 (112 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey.ndm.kabat’ saved [8216]
#
# --2016-10-22 06:59:04--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey.pdm.imgt
#            => ‘internal_data/rhesus_monkey/rhesus_monkey.pdm.imgt’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey.pdm.imgt ... done.
# Length: 7115 (6.9K)
#
#      0K ......                                                100%  103K=0.07s
#
# 2016-10-22 06:59:05 (103 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey.pdm.imgt’ saved [7115]
#
# --2016-10-22 06:59:05--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey.pdm.kabat
#            => ‘internal_data/rhesus_monkey/rhesus_monkey.pdm.kabat’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey.pdm.kabat ... done.
# Length: 7046 (6.9K)
#
#      0K ......                                                100% 36.5K=0.2s
#
# 2016-10-22 06:59:05 (36.5 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey.pdm.kabat’ saved [7046]
#
# --2016-10-22 06:59:05--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_D.nhr
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_D.nhr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_D.nhr ... done.
# Length: 2016 (2.0K)
#
#      0K .                                                     100% 15.8K=0.1s
#
# 2016-10-22 06:59:06 (15.8 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_D.nhr’ saved [2016]
#
# --2016-10-22 06:59:06--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_D.nin
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_D.nin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_D.nin ... done.
# Length: 476
#
#      0K                                                       100% 3.32K=0.1s
#
# 2016-10-22 06:59:07 (3.32 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_D.nin’ saved [476]
#
# --2016-10-22 06:59:07--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_D.nog
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_D.nog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_D.nog ... done.
# Length: 160
#
#      0K                                                       100% 6.85K=0.02s
#
# 2016-10-22 06:59:07 (6.85 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_D.nog’ saved [160]
#
# --2016-10-22 06:59:07--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_D.nsd
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_D.nsd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_D.nsd ... done.
# Length: 1004
#
#      0K                                                       100% 36.3K=0.03s
#
# 2016-10-22 06:59:08 (36.3 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_D.nsd’ saved [1004]
#
# --2016-10-22 06:59:08--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_D.nsi
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_D.nsi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_D.nsi ... done.
# Length: 65
#
#      0K                                                       100%  226 =0.3s
#
# 2016-10-22 06:59:08 (226 B/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_D.nsi’ saved [65]
#
# --2016-10-22 06:59:08--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_D.nsq
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_D.nsq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_D.nsq ... done.
# Length: 202
#
#      0K                                                       100% 2.08K=0.09s
#
# 2016-10-22 06:59:09 (2.08 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_D.nsq’ saved [202]
#
# --2016-10-22 06:59:09--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_J.nhr
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_J.nhr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_J.nhr ... done.
# Length: 1167 (1.1K)
#
#      0K .                                                     100% 25.3K=0.05s
#
# 2016-10-22 06:59:09 (25.3 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_J.nhr’ saved [1167]
#
# --2016-10-22 06:59:09--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_J.nin
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_J.nin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_J.nin ... done.
# Length: 332
#
#      0K                                                       100% 11.1K=0.03s
#
# 2016-10-22 06:59:10 (11.1 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_J.nin’ saved [332]
#
# --2016-10-22 06:59:10--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_J.nog
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_J.nog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_J.nog ... done.
# Length: 112
#
#      0K                                                       100% 10.4K=0.01s
#
# 2016-10-22 06:59:11 (10.4 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_J.nog’ saved [112]
#
# --2016-10-22 06:59:11--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_J.nsd
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_J.nsd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_J.nsd ... done.
# Length: 434
#
#      0K                                                       100% 22.6K=0.02s
#
# 2016-10-22 06:59:11 (22.6 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_J.nsd’ saved [434]
#
# --2016-10-22 06:59:11--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_J.nsi
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_J.nsi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_J.nsi ... done.
# Length: 63
#
#      0K                                                       100% 13.9M=0s
#
# 2016-10-22 06:59:11 (13.9 MB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_J.nsi’ saved [63]
#
# --2016-10-22 06:59:11--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_J.nsq
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_J.nsq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_J.nsq ... done.
# Length: 228
#
#      0K                                                       100% 3.35K=0.07s
#
# 2016-10-22 06:59:12 (3.35 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_J.nsq’ saved [228]
#
# --2016-10-22 06:59:12--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.nhr
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.nhr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.nhr ... done.
# Length: 10484 (10K)
#
#      0K ..........                                            100%  429K=0.02s
#
# 2016-10-22 06:59:13 (429 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.nhr’ saved [10484]
#
# --2016-10-22 06:59:13--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.nin
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.nin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.nin ... done.
# Length: 2216 (2.2K)
#
#      0K ..                                                    100% 85.2K=0.03s
#
# 2016-10-22 06:59:13 (85.2 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.nin’ saved [2216]
#
# --2016-10-22 06:59:13--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.nog
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.nog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.nog ... done.
# Length: 740
#
#      0K                                                       100% 25.7K=0.03s
#
# 2016-10-22 06:59:14 (25.7 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.nog’ saved [740]
#
# --2016-10-22 06:59:14--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.nsd
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.nsd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.nsd ... done.
# Length: 4342 (4.2K)
#
#      0K ....                                                  100%  468K=0.009s
#
# 2016-10-22 06:59:14 (468 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.nsd’ saved [4342]
#
# --2016-10-22 06:59:14--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.nsi
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.nsi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.nsi ... done.
# Length: 168
#
#      0K                                                       100% 9.73K=0.02s
#
# 2016-10-22 06:59:15 (9.73 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.nsi’ saved [168]
#
# --2016-10-22 06:59:15--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.nsq
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.nsq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.nsq ... done.
# Length: 13134 (13K)
#
#      0K .......... ..                                         100%  385K=0.03s
#
# 2016-10-22 06:59:15 (385 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.nsq’ saved [13134]
#
# --2016-10-22 06:59:15--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.phr
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.phr’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.phr ... done.
# Length: 10423 (10K)
#
#      0K ..........                                            100% 54.2K=0.2s
#
# 2016-10-22 06:59:16 (54.2 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.phr’ saved [10423]
#
# --2016-10-22 06:59:16--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.pin
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.pin’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.pin ... done.
# Length: 1512 (1.5K)
#
#      0K .                                                     100% 77.6K=0.02s
#
# 2016-10-22 06:59:16 (77.6 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.pin’ saved [1512]
#
# --2016-10-22 06:59:16--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.pog
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.pog’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.pog ... done.
# Length: 740
#
#      0K                                                       100% 18.8K=0.04s
#
# 2016-10-22 06:59:17 (18.8 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.pog’ saved [740]
#
# --2016-10-22 06:59:17--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.psd
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.psd’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.psd ... done.
# Length: 4342 (4.2K)
#
#      0K ....                                                  100%  273K=0.02s
#
# 2016-10-22 06:59:17 (273 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.psd’ saved [4342]
#
# --2016-10-22 06:59:17--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.psi
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.psi’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.psi ... done.
# Length: 168
#
#      0K                                                       100% 4.26K=0.04s
#
# 2016-10-22 06:59:18 (4.26 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.psi’ saved [168]
#
# --2016-10-22 06:59:18--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/rhesus_monkey_V.psq
#            => ‘internal_data/rhesus_monkey/rhesus_monkey_V.psq’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_V.psq ... done.
# Length: 17591 (17K)
#
#      0K .......... .......                                    100%  109K=0.2s
#
# 2016-10-22 06:59:18 (109 KB/s) - ‘internal_data/rhesus_monkey/rhesus_monkey_V.psq’ saved [17591]
#
# --2016-10-22 06:59:18--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/CVS/internal_data
#            => ‘internal_data/rhesus_monkey/CVS/.listing’
# ==> CWD (1) /blast/executables/igblast/release/internal_data/rhesus_monkey/CVS ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K                                                        41.4K=0.005s
#
# 2016-10-22 06:59:19 (41.4 KB/s) - ‘internal_data/rhesus_monkey/CVS/.listing’ saved [195]
#
# Removed ‘internal_data/rhesus_monkey/CVS/.listing’.
# --2016-10-22 06:59:19--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/CVS/Entries
#            => ‘internal_data/rhesus_monkey/CVS/Entries’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR Entries ... done.
# Length: 1093 (1.1K)
#
#      0K .                                                     100% 66.1K=0.02s
#
# 2016-10-22 06:59:20 (66.1 KB/s) - ‘internal_data/rhesus_monkey/CVS/Entries’ saved [1093]
#
# --2016-10-22 06:59:20--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/CVS/Repository
#            => ‘internal_data/rhesus_monkey/CVS/Repository’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR Repository ... done.
# Length: 59
#
#      0K                                                       100% 31.1K=0.002s
#
# 2016-10-22 06:59:20 (31.1 KB/s) - ‘internal_data/rhesus_monkey/CVS/Repository’ saved [59]
#
# --2016-10-22 06:59:20--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/internal_data/rhesus_monkey/CVS/Root
#            => ‘internal_data/rhesus_monkey/CVS/Root’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR Root ... done.
# Length: 46
#
#      0K                                                       100% 30.2K=0.001s
#
# 2016-10-22 06:59:21 (30.2 KB/s) - ‘internal_data/rhesus_monkey/CVS/Root’ saved [46]
#
# FINISHED --2016-10-22 06:59:21--
# Total wall clock time: 1m 16s
# Downloaded: 119 files, 1.0M in 11s (89.5 KB/s)
# --2016-10-22 06:59:21--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/optional_file
#            => ‘.listing’
# Resolving ftp.ncbi.nih.gov (ftp.ncbi.nih.gov)... 130.14.250.13, 2607:f220:41e:250::10
# Connecting to ftp.ncbi.nih.gov (ftp.ncbi.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /blast/executables/igblast/release ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K                                                         228K=0.003s
#
# 2016-10-22 06:59:22 (228 KB/s) - ‘.listing’ saved [599]
#
# Removed ‘.listing’.
# --2016-10-22 06:59:22--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/optional_file/optional_file
#            => ‘optional_file/.listing’
# ==> CWD (1) /blast/executables/igblast/release/optional_file ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#      0K                                                         129K=0.003s
#
# 2016-10-22 06:59:23 (129 KB/s) - ‘optional_file/.listing’ saved [436]
#
# Removed ‘optional_file/.listing’.
# --2016-10-22 06:59:23--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/optional_file/human_gl.aux
#            => ‘optional_file/human_gl.aux’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_gl.aux ... done.
# Length: 2843 (2.8K)
#
#      0K ..                                                    100%  136K=0.02s
#
# 2016-10-22 06:59:23 (136 KB/s) - ‘optional_file/human_gl.aux’ saved [2843]
#
# --2016-10-22 06:59:23--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/optional_file/human_gl.aux.testonly
#            => ‘optional_file/human_gl.aux.testonly’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR human_gl.aux.testonly ... done.
# Length: 456
#
#      0K                                                       100% 11.3K=0.04s
#
# 2016-10-22 06:59:24 (11.3 KB/s) - ‘optional_file/human_gl.aux.testonly’ saved [456]
#
# --2016-10-22 06:59:24--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/optional_file/mouse_gl.aux
#            => ‘optional_file/mouse_gl.aux’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR mouse_gl.aux ... done.
# Length: 3813 (3.7K)
#
#      0K ...                                                   100% 52.6K=0.07s
#
# 2016-10-22 06:59:24 (52.6 KB/s) - ‘optional_file/mouse_gl.aux’ saved [3813]
#
# --2016-10-22 06:59:24--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/optional_file/rabbit_gl.aux
#            => ‘optional_file/rabbit_gl.aux’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rabbit_gl.aux ... done.
# Length: 1058 (1.0K)
#
#      0K .                                                     100% 47.0K=0.02s
#
# 2016-10-22 06:59:25 (47.0 KB/s) - ‘optional_file/rabbit_gl.aux’ saved [1058]
#
# --2016-10-22 06:59:25--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/optional_file/rat_gl.aux
#            => ‘optional_file/rat_gl.aux’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rat_gl.aux ... done.
# Length: 501
#
#      0K                                                       100% 1.53K=0.3s
#
# 2016-10-22 06:59:26 (1.53 KB/s) - ‘optional_file/rat_gl.aux’ saved [501]
#
# --2016-10-22 06:59:26--  ftp://ftp.ncbi.nih.gov/blast/executables/igblast/release/optional_file/rhesus_monkey_gl.aux
#            => ‘optional_file/rhesus_monkey_gl.aux’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR rhesus_monkey_gl.aux ... done.
# Length: 568
#
#      0K                                                       100% 1004K=0.001s
#
# 2016-10-22 06:59:27 (1004 KB/s) - ‘optional_file/rhesus_monkey_gl.aux’ saved [568]
#
# FINISHED --2016-10-22 06:59:27--
# Total wall clock time: 6.1s
# Downloaded: 6 files, 9.0K in 0.5s (18.9 KB/s)

# %%
# %%bash
# mkdir database
# # V-segment database
# perl ./edit_imgt_file.pl IMGT_Human_IGHV.fasta > database/human_igh_v
# makeblastdb -parse_seqids -dbtype nucl -in database/human_igh_v
# # D-segment database
# perl ./edit_imgt_file.pl IMGT_Human_IGHD.fasta > database/human_igh_d
# makeblastdb -parse_seqids -dbtype nucl -in database/human_igh_d
# # J-segment database
# perl ./edit_imgt_file.pl IMGT_Human_IGHJ.fasta > database/human_igh_j
# makeblastdb -parse_seqids -dbtype nucl -in database/human_igh_j
# Out:
# Building a new DB, current time: 10/22/2016 07:01:03
# New DB name:   /home/simon/Projects/aairr16/solutions/database/human_igh_v
# New DB title:  database/human_igh_v
# Sequence type: Nucleotide
# Keep Linkouts: T
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 350 sequences in 0.00901294 seconds.
#
#
# Building a new DB, current time: 10/22/2016 07:01:03
# New DB name:   /home/simon/Projects/aairr16/solutions/database/human_igh_d
# New DB title:  database/human_igh_d
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/simon/Projects/aairr16/solutions/database/human_igh_d
# Keep Linkouts: T
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 44 sequences in 0.00116992 seconds.
#
#
# Building a new DB, current time: 10/22/2016 07:01:03
# New DB name:   /home/simon/Projects/aairr16/solutions/database/human_igh_j
# New DB title:  database/human_igh_j
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/simon/Projects/aairr16/solutions/database/human_igh_j
# Keep Linkouts: T
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 13 sequences in 0.000507832 seconds.

# %% [markdown]
# ##  Convert FASTQ to FASTA

# %%
from Bio import SeqIO
SeqIO.convert('S43_atleast-2.fastq','fastq','S43_atleast-2.fasta','fasta')
# Out:
# 100

# %% [markdown]
# ## Use IgBLAST

# %%
# %%bash
# igblastn \
#     -germline_db_V database/human_igh_v \
#     -germline_db_D database/human_igh_d \
#     -germline_db_J database/human_igh_j \
#     -auxiliary_data optional_file/human_gl.aux \
#     -domain_system imgt -ig_seqtype Ig -organism human \
#     -outfmt '7 std qseq sseq btop' \
#     -query SRR765688.fasta \
#     -out SRR765688.fmt7

# %% [markdown]
# ## Postprocess IgBLAST

# %%
# %%bash
# MakeDb.py igblast -i SRR765688.fmt7 -s SRR765688.fasta -r IMGT_Human_IGH[VDJ].fasta \
#     --regions --scores
# Out:
#         START> MakeDB
#       ALIGNER> IgBlast
# ALIGN_RESULTS> SRR765688.fmt7
#      SEQ_FILE> SRR765688.fasta
#      NO_PARSE> False
#  SCORE_FIELDS> True
# REGION_FIELDS> True
#
# PROGRESS> 07:54:56 [####################] 100% (2,561) 0.2 min
#
# OUTPUT> SRR765688_db-pass.tab
#   PASS> 2553
#   FAIL> 8
#    END> MakeDb

# %%
# %%bash
# ParseDb.py split -d SRR765688_db-pass.tab -f FUNCTIONAL
# Out:
#     START> ParseDb
#   COMMAND> split
#      FILE> SRR765688_db-pass.tab
#     FIELD> FUNCTIONAL
# NUM_SPLIT> None
#
# PROGRESS> 07:55:05 [####################] 100% (2,553) 0.0 min
#
# OUTPUT1> SRR765688_db-pass_FUNCTIONAL-F.tab
# OUTPUT2> SRR765688_db-pass_FUNCTIONAL-T.tab
# RECORDS> 2553
#   PARTS> 2
#     END> ParseDb
